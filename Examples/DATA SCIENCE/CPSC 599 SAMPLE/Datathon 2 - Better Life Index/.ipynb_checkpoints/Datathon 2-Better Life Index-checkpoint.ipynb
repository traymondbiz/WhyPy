# %% [markdown]
# # Basic Imports

# %%
import numpy as np  #load up the libraries and object defs. we need
import pandas as pd
from pandas import DataFrame, Series

# load up my visualization system, and call the object plt
import matplotlib.pyplot as plt

# tell ipython notebook to print visualizations inline
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load Data

# %%
# A subset of data from the OECD Better Life Index (...and an incomplete one at that)
df = pd.read_excel('BetterLifeIndex.xlsx',skiprows=2) # Drop the non-data rows at the top

# %%
df.head(5) # Get a quick sample
# Out:
#      Country  Employment rate  Long-term unemployment rate  Student skills  \
# 0  Australia               72                         1.32             512
# 1    Austria               71                         1.53             500
# 2    Belgium               62                         4.26             509
# 3     Canada               72                         0.89             522
# 4      Chile               62                         1.67             436
#
#    Years in education  Air pollution  Water quality  Life expectancy  \
# 0                19.2              6             94             82.2
# 1                17.1             15             93             81.2
# 2                18.8             19             83             80.7
# 3                16.3             12             90             81.5
# 4                17.1             18             71             78.8
#
#    Life satisfaction  Feeling safe walking alone at night  Homicide rate
# 0                7.3                                 62.6            0.8
# 1                7.1                                 81.2            0.4
# 2                6.9                                 69.6            1.1
# 3                7.4                                 81.7            1.5
# 4                6.5                                 50.2            3.8

# %%
# We can do math with these
df["Homicide rate"] + df["Feeling safe walking alone at night"]
# Out:
# 0     63.4
# 1     81.6
# 2     70.7
# 3     83.2
# 4     54.0
# 5     71.0
# 6     85.5
# 7     72.0
# 8     87.3
# 9     71.2
# 10    75.1
# 11    64.0
# 12    54.4
# 13    78.4
# 14    77.8
# 15    68.1
# 16    60.1
# 17    70.5
# 18    68.8
# 19    67.7
# 20    70.8
# 21    63.3
# 22    81.3
# 23    65.6
# 24    90.6
# 25    67.1
# 26    70.1
# 27    63.3
# 28    84.3
# 29    82.2
# 30    77.6
# 31    87.9
# 32    62.1
# 33    78.0
# 34    79.1
# dtype: float64

# %%
# We might want to consider normalizing these so they're weighted more evenly
hr = df["Homicide rate"] 
df["Homicide rate (normalized)"] = (hr-hr.min())/(hr.max()-hr.min())

lr = df["Feeling safe walking alone at night"]
df["Feeling safe walking alone at night (normalized)"] = (lr-lr.min())/(lr.max()-lr.min())
df.sample(5)
# Out:
#     Country  Employment rate  Long-term unemployment rate  Student skills  \
# 16    Italy               57                         7.79             490
# 14  Ireland               61                         6.98             516
# 21   Mexico               60                         0.06             417
# 10  Germany               74                         2.21             515
# 9    France               64                         4.21             500
#
#     Years in education  Air pollution  Water quality  Life expectancy  \
# 16                16.8             18             70             82.8
# 14                17.8              8             82             81.1
# 21                14.4             12             68             74.6
# 10                18.1             15             94             80.9
# 9                 16.4             14             84             82.3
#
#     Life satisfaction  Feeling safe walking alone at night  Homicide rate  \
# 16                5.8                                 59.3            0.8
# 14                6.8                                 77.0            0.8
# 21                6.2                                 39.9           23.4
# 10                7.0                                 74.6            0.5
# 9                 6.4                                 70.6            0.6
#
#     Homicide rate (normalized)  \
# 16                    0.025862
# 14                    0.025862
# 21                    1.000000
# 10                    0.012931
# 9                     0.017241
#
#     Feeling safe walking alone at night (normalized)
# 16                                          0.390342
# 14                                          0.746479
# 21                                          0.000000
# 10                                          0.698189
# 9                                           0.617706

# %%
# A different way to perform computations on a whole column
df[['Homicide rate']].apply(lambda x: (x - x.mean()) / (x.max() - x.min())) # (here normalized distance from the mean)
# Out:
#     Homicide rate
# 0       -0.050739
# 1       -0.067980
# 2       -0.037808
# 3       -0.020567
# 4        0.078571
# 5       -0.046429
# 6       -0.072291
# 7        0.121675
# 8       -0.020567
# 9       -0.059360
# 10      -0.063670
# 11      -0.020567
# 12      -0.033498
# 13      -0.072291
# 14      -0.050739
# 15      -0.007635
# 16      -0.050739
# 17      -0.072291
# 18      -0.037808
# 19       0.177709
# 20      -0.076601
# 21       0.923399
# 22      -0.050739
# 23      -0.033498
# 24      -0.042118
# 25      -0.042118
# 26      -0.046429
# 27      -0.033498
# 28      -0.067980
# 29      -0.059360
# 30      -0.050739
# 31      -0.063670
# 32      -0.011946
# 33      -0.076601
# 34       0.138916

# %%
# In case you want to index by country (remember that this creates a copy of the DataFrame)
df.set_index('Country')
# Out:
#                  Employment rate  Long-term unemployment rate  Student skills  \
# Country
# Australia                     72                         1.32             512
# Austria                       71                         1.53             500
# Belgium                       62                         4.26             509
# Canada                        72                         0.89             522
# Chile                         62                         1.67             436
# Czech Republic                69                         2.72             500
# Denmark                       73                         1.66             498
# Estonia                       70                         3.32             526
# Finland                       69                         1.97             529
# France                        64                         4.21             500
# Germany                       74                         2.21             515
# Greece                        49                        19.47             466
# Hungary                       62                         3.78             487
# Iceland                       82                         0.67             484
# Ireland                       61                         6.98             516
# Israel                        68                         0.63             474
# Italy                         57                         7.79             490
# Japan                         73                         1.36             540
# Korea                         65                         0.01             542
# Latvia                        66                         4.67             494
# Luxembourg                    67                         1.60             490
# Mexico                        60                         0.06             417
# Netherlands                   73                         2.98             519
# New Zealand                   74                         0.78             509
# Norway                        75                         0.41             496
# Poland                        62                         3.26             521
# Portugal                      63                         8.28             488
# Slovak Republic               61                         8.80             472
# Slovenia                      64                         5.27             499
# Spain                         57                        12.92             490
# Sweden                        75                         1.33             482
# Switzerland                   80                         1.71             518
# Turkey                        50                         2.04             462
# United Kingdom                73                         2.22             502
# United States                 68                         1.42             492
#
#                  Years in education  Air pollution  Water quality  \
# Country
# Australia                      19.2              6             94
# Austria                        17.1             15             93
# Belgium                        18.8             19             83
# Canada                         16.3             12             90
# Chile                          17.1             18             71
# Czech Republic                 17.4             17             88
# Denmark                        19.6             11             95
# Estonia                        17.8              9             84
# Finland                        19.7              7             94
# France                         16.4             14             84
# Germany                        18.1             15             94
# Greece                         18.5             15             69
# Hungary                        17.2             16             76
# Iceland                        19.6              7             97
# Ireland                        17.8              8             82
# Israel                         15.9             26             65
# Italy                          16.8             18             70
# Japan                          16.0             16             87
# Korea                          17.5             29             78
# Latvia                         17.8             12             76
# Luxembourg                     15.1             15             85
# Mexico                         14.4             12             68
# Netherlands                    17.9             17             94
# New Zealand                    18.0              9             92
# Norway                         18.0              6             97
# Poland                         17.9             17             80
# Portugal                       17.4             10             89
# Slovak Republic                16.2             16             81
# Slovenia                       18.3             14             91
# Spain                          17.7             12             71
# Sweden                         19.1              7             95
# Switzerland                    17.4             17             97
# Turkey                         16.9             17             63
# United Kingdom                 16.7             11             87
# United States                  17.1             11             84
#                  Feeling safe walking alone at night (normalized)
# Country
# Australia                                                0.456740
# Austria                                                  0.830986
# Belgium                                                  0.597586
# Canada                                                   0.841046
# Chile                                                    0.207243
# Czech Republic                                           0.607646
# Denmark                                                  0.911469
# Estonia                                                  0.549296
# Finland                                                  0.923541
# France                                                   0.617706
# Germany                                                  0.698189
# Greece                                                   0.454728
# Hungary                                                  0.267606
# Iceland                                                  0.768612
# Ireland                                                  0.746479
# Israel                                                   0.531187
# Italy                                                    0.390342
# Japan                                                    0.609658
# Korea                                                    0.559356
# Latvia                                                   0.436620
# Luxembourg                                               0.617706
# Mexico                                                   0.000000
# Netherlands                                              0.816901
# New Zealand                                              0.492958
# Norway                                                   1.000000
# Poland                                                   0.527163
# Portugal                                                 0.589537
# Slovak Republic                                          0.446680
# Slovenia                                                 0.885312
# Spain                                                    0.839034
# Sweden                                                   0.742455
# Switzerland                                              0.955734
# Turkey                                                   0.412475
# United Kingdom                                           0.762575
# United States                                            0.684105

# %% [markdown]
# # Question 1
# What country is the safest?
#
# *Remember, you should be able to clearly **present** the result to an audience (and have them understand how you got it.)*

# %%
country_df = df.set_index("Country")
def rowCalc(row):
    return row["Feeling safe walking alone at night (normalized)"] - row["Homicide rate (normalized)"]

safety = country_df[['Feeling safe walking alone at night (normalized)','Homicide rate (normalized)']].copy()
safety['Safety'] = safety.apply(lambda row: rowCalc(row), axis=1)
maxCol = safety['Safety'].idxmax()
safety[maxCol:maxCol]
# Out:
#          Feeling safe walking alone at night (normalized)  \
# Country
# Norway                                                1.0
#
#          Homicide rate (normalized)    Safety
# Country
# Norway                     0.034483  0.965517

# %% [markdown]
# # Question 2
# On average what is the **life satisfaction** of the five countries with the **most years in education**?

# %%
country_data = country_df.sort_values(['Years in education'], ascending=False)
top5Edu = country_data.head(n=5)
print(top5Edu[['Life satisfaction','Years in education']])
print()
print("Average life satisfaction for countries with most years in education: " + str(top5Edu['Life satisfaction'].mean()))
# Out:
#            Life satisfaction  Years in education
# Country
# Finland                  7.4                19.7
# Denmark                  7.5                19.6
# Iceland                  7.5                19.6
# Australia                7.3                19.2
# Sweden                   7.3                19.1
#
# Average life satisfaction for countries with most years in education: 7.4

# %% [markdown]
# # Question 3
# What is the distribution of life expectancy across OECD countries?
# Are there other indicators with similar distributions? Do you think they are related?

# %%
country_df["Life expectancy"].hist()

# %%
_ = country_df[['Employment rate','Long-term unemployment rate','Student skills','Years in education','Air pollution','Water quality','Life expectancy','Life satisfaction','Feeling safe walking alone at night','Homicide rate']].hist(bins=15,figsize=(17,8),layout=(2,5))

# %% [markdown]
# # Question 4
# {Your choice}

# %%
#Pulling data out of main file.
pull = df.sort_values('Life satisfaction', ascending=False)

#Information being put into a frame.
country = pull['Country']
unemploymentRate = pull['Long-term unemployment rate']
lifeSatisfaction = pull['Life satisfaction']

lSat = pd.DataFrame({'Country': country, 
                     'Long-Term Unemployment Rate': unemploymentRate, 
                     'Life Satisfaction': lifeSatisfaction})
lSat = lSat.set_index('Country')

#Show results.
lSat.plot(kind="scatter", x="Long-Term Unemployment Rate", y="Life Satisfaction")

# %% [markdown]
# # Question 5
# {Your choice}
